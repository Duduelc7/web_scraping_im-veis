# %%
from numpy import arange
from pkg_resources import ensure_directory
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = 'https://www.vivareal.com.br/venda/parana/curitiba/apartamento_residencial/?pagina={}'

# %%
i = 1
ret = requests.get(url.format(i))
soup = bs(ret.text)
# Out:
# <ipython-input-3-9f5fd2981dea>:3: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 3 of the file c:\Users\eduar\OneDrive\Área de Trabalho\Ciencia da Computação\How -- Bootcamp\banco_imóveis.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = bs(ret.text)

# %%
houses = soup.find_all('a', {'class': 'property-card__content-link js-card-title'})
qntd_imoveis = float(soup.find('strong', {'class': 'results-summary__count'}).text.replace('.',''))

# %%
house = houses[0]

# %%
print(f"""{descricao}
    End: {endereco}
    Area: {area}m²
    Quartos: {quartos}
    Banheiros: {wc}
    Vagas: {vagas}
    Valor: {valor}
    Condominio: {condominio}
    Link: {link}""")
# Out:
# Apartamento com 3 Quartos à Venda, 67m²
#     End: Rua Mário Chalbaud Biscaia, 782 - Novo Mundo, Curitiba - PR
#     Area: 67m²
#     Quartos: 3
#     Banheiros: 2
#     Vagas: 1
#     Valor: R$ 340.000
#     Condominio: R$ 320
#     Link: https://www.vivareal.com.br/imovel/apartamento-3-quartos-novo-mundo-bairros-curitiba-com-garagem-67m2-venda-RS340000-id-2522878143/

# %%
df
# Out:
#                                      descricao  \
# 0      Apartamento com 2 Quartos à Venda, 61m²
# 1                                          MUV
# 2      Apartamento com 3 Quartos à Venda, 83m²
# 3     Apartamento com 4 Quartos à Venda, 216m²
# 4     Apartamento com 2 Quartos à Venda, 244m²
# ...                                        ...
# 1363   Apartamento com 3 Quartos à Venda, 53m²
# 1364   Apartamento com 2 Quartos à Venda, 76m²
# 1365  Apartamento com 3 Quartos à Venda, 128m²
# 1366  Apartamento com 3 Quartos à Venda, 140m²
# 1367   Apartamento com 3 Quartos à Venda, 67m²
#
#                                                endereco   area quartos wc  \
# 0     Rua João Alencar Guimarães, 1745 - Campo Compr...     61       2  2
# 1     Avenida Visconde de Guarapuava, 3070 - Centro,...  20-36       1  1
# 2     Avenida Cândido Hartmann, 3530 - Santo Inácio,...     83       3  2
# 3       Rua Lamenha Lins, 601 - Rebouças, Curitiba - PR    216       4  4
# 4     Rua Paulo Gorski, 1837 - Mossunguê, Curitiba - PR    244       2  3
# ...                                                 ...    ...     ... ..
# 1363  Rua João Dembinski, 2380 - Cidade Industrial, ...     53       3  1
# 1364  Rua Comendador Macedo, 324 - Centro, Curitiba ...     76       2  1
# 1365  Rua Engenheiro Niepce da Silva, 144 - Portão, ...    128       3  5
# 1366   Rua Gago Coutinho, 45 - Bacacheri, Curitiba - PR    140       3  4
# 1367  Rua Mário Chalbaud Biscaia, 782 - Novo Mundo, ...     67       3  2
#
#      vagas                     valor condominio  \
# 0        1                R$ 338.000     R$ 500
# 1       --  A partir de   R$ 161.000       None
# 2        1                R$ 560.000     R$ 594
# 3        1                R$ 680.000       None
# 4        2              R$ 1.400.000   R$ 1.000
# ...    ...                       ...        ...
# 1363     1                R$ 185.000     R$ 359
# 1364    --                R$ 240.000     R$ 500
# 1365     2              R$ 1.190.000     R$ 942
# 1366     2                R$ 930.000     R$ 950
# 1367     1                R$ 340.000     R$ 320
#
#                                                    link
# 0     https://www.vivareal.com.br/imovel/apartamento...
# 1     https://www.vivareal.com.br/imoveis-lancamento...
# 2     https://www.vivareal.com.br/imovel/apartamento...
# 3     https://www.vivareal.com.br/imovel/apartamento...
# 4     https://www.vivareal.com.br/imovel/apartamento...
# ...                                                 ...
# 1363  https://www.vivareal.com.br/imovel/apartamento...
# 1364  https://www.vivareal.com.br/imovel/apartamento...
# 1365  https://www.vivareal.com.br/imovel/apartamento...
# 1366  https://www.vivareal.com.br/imovel/apartamento...
# 1367  https://www.vivareal.com.br/imovel/apartamento...
#
# [1368 rows x 9 columns]
